# %% [markdown]
# <a href="https://colab.research.google.com/github/kittikhun62/data_viz_2022/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd     # pandas ใช้จัดการข้อมูลที่เป็นตาราง
import os       # os ใช้จัดการกับไฟล์ ว่าอยู่ที่ไหน

# %%
from google.colab import drive      # ชี้ไฟล์ที่อยู่ใน google drive เพื่อเชื่อมต่อไฟล์
drive.mount('/content/drive')
path = '/content/drive/My Drive/final'      # ชี้ dirve ที่เราต้องการ
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_file_path = os.path.join(path,'confirmed-cases-since-280265.xlsx')   
data_cases = pd.read_excel(data_file_path)

# %%
data_cases
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617    2022-02-28    2022-02-27   ชาย  41.0   ปี    Thailand
# 1       2869618    2022-02-28    2022-02-27  หญิง  45.0   ปี    Thailand
# 2       2869619    2022-02-28    2022-02-27  หญิง  40.0   ปี    Thailand
# 3       2869620    2022-02-28    2022-02-27   ชาย  44.0   ปี    Thailand
# 4       2869621    2022-02-28    2022-02-27   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 484348  3353965    2022-03-20    2022-03-19   ชาย   NaN  NaN         NaN
# 484349  3353966    2022-03-20    2022-03-19   ชาย   NaN  NaN         NaN
# 484350  3353967    2022-03-20    2022-03-19   ชาย   NaN  NaN         NaN
# 484351  3353968    2022-03-20    2022-03-19   ชาย   NaN  NaN         NaN
# 484352  3353969    2022-03-20    2022-03-19   ชาย   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %%
data_file_path = os.path.join(path,'confirmed-cases-since-271064.xlsx')   
data_cases1 = pd.read_excel(data_file_path)

# %%
data_cases1
# Out:
#              No. announce_date Notified date   sex  age Unit nationality  \
# 0        1859158    2021-10-26    2021-10-25   ชาย   20   ปี    Thailand
# 1        1859159    2021-10-26    2021-10-25  หญิง   42   ปี    Thailand
# 2        1859160    2021-10-26    2021-10-25  หญิง   33   ปี    Thailand
# 3        1859161    2021-10-26    2021-10-25  หญิง   52   ปี    Thailand
# 4        1859162    2021-10-26    2021-10-25  หญิง   84   ปี    Thailand
# ...          ...           ...           ...   ...  ...  ...         ...
# 1010454  2869612    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010455  2869613    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010456  2869614    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010457  2869615    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010458  2869616    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# ...

# %%
data_cases_PD = pd.concat([data_cases,data_cases1])
data_cases_PD
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        2869617    2022-02-28    2022-02-27   ชาย  41.0   ปี    Thailand
# 1        2869618    2022-02-28    2022-02-27  หญิง  45.0   ปี    Thailand
# 2        2869619    2022-02-28    2022-02-27  หญิง  40.0   ปี    Thailand
# 3        2869620    2022-02-28    2022-02-27   ชาย  44.0   ปี    Thailand
# 4        2869621    2022-02-28    2022-02-27   ชาย  11.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612    2022-02-27    2022-02-26   ชาย   NaN  NaN         NaN
# 1010455  2869613    2022-02-27    2022-02-26   ชาย   NaN  NaN         NaN
# 1010456  2869614    2022-02-27    2022-02-26   ชาย   NaN  NaN         NaN
# 1010457  2869615    2022-02-27    2022-02-26   ชาย   NaN  NaN         NaN
# 1010458  2869616    2022-02-27    2022-02-26   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %%
data_cases_all = data_cases_PD[(data_cases_PD['announce_date']>='2022-03-01') & (data_cases_PD['announce_date']<='2022-03-04')]
