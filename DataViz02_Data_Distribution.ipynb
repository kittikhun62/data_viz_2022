# %% [markdown]
# <a href="https://colab.research.google.com/github/kittikhun62/data_viz_2022/blob/main/DataViz02_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd #นำข้อมูลเข้า เมื่อจัดการตารางเล็กน้อย

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv') #อ่านไฟล์ข้อมูล
df.head() #แสดงข้อมูลออกมาให้รูปแบบตารางเอาแต่บ้านบน
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Scatter Plot

# %%
from matplotlib import pyplot as plt #ข้างหน้าทั้งหมดเราจะย่อเป็น plt

# %%
plt.scatter([1,-1],[2,-1]) # X เป็น 1 y เป็น 2 และ x เป็น -1 y เป็น -1

# %%
plt.scatter(df['PetalLength'],df['SepalLength']) #เปรียบเทียบความยาวของกลีบดอกกับความยาวของกรีบเลี้ยง

# %% [markdown]
# ## เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'], c='r') #เปลี่ยนสีเป็นสีแดง

# %% [markdown]
# ## ระบุสีให้แต่ละจุด

# %%
set(df['Name']) #ดูว่ามีพันธุอะไรบ้าง
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ### แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี (r g b c m y k w)

# %%
df2 = df.replace({'Iris-setosa':'r' , 'Iris-versicolor':'g','Iris-virginica' : 'b'}) #แทนสีแต่ละอัน

# %%
df2.head() #แสดงตารางออกมาเอาแต่ส่วนหัว
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name']) #พล็อตกราฟออกมาดู

# %% [markdown]
# ## เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name']) #เชลล์นี้ทำการวาดกราฟ
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อ matker

# %%
plt.scatter(df2['PetalLength'][:50] ,df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa') #50 อันแรก
plt.scatter(df2['PetalLength'][50:100] ,df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')  #50-100
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga') #100
plt.legend() #โชว์ชื่อแต่ละจุดที่พล็อตไปด้วย
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50] ,df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa') #50 อันแรก
plt.scatter(df2['PetalLength'][50:100] ,df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')  #50-100
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga') #100
plt.legend() #โชว์ชื่อแต่ละจุดที่พล็อตไปด้วย
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
plt.title('Comparing petal&sepal length of different iris flowers'); #ตั้งืชื่อกราฟ

# %% [markdown]
# ## ใช้ขนาดของ marker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50] ,df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50]) #50 อันแรก
plt.scatter(df2['PetalLength'][50:100] ,df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100])  #50-100
plt.scatter(df2['PetalLength'][100:] ,df2['SepalLength'][100:],c=df2['Name'][100:],label='versicolor',s=df2['PetalWidth'][100:])  #100 สุดท้าย
plt.legend()  #โชว์ชื่อแต่ละจุดที่พล็อตไปด้วย
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
plt.title('comparing petal & sepal length of different iris flowers'); #ตั้งชื่อกราฟ
#จะเห็นว่ากราฟมีขนาดเล็กมองไม่ชัด

# %% [markdown]
# - ขยายขนาดของ marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50] ,df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50]) #50 อันแรก #เพิ่มขนาด 40 เท่าของภาพเดิม
plt.scatter(df2['PetalLength'][50:100] ,df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])  #50-100 #เพิ่มขนาด 40 เท่าของภาพเดิม
plt.scatter(df2['PetalLength'][100:] ,df2['SepalLength'][100:],c=df2['Name'][100:],label='versicolor',s=40*df2['PetalWidth'][100:])  #100 สุดท้าย #เพิ่มขนาด 40 เท่าของภาพเดิม
plt.legend() #โชว์ชื่อแต่ละจุดที่พล็อตไปด้วย
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
plt.title('comparing petal & sepal length of different iris flowers'); #ตั้งชื่อกราฟ

# %% [markdown]
# ## ปรับความโปร่งใสของ maker เพื่อให้มองเห็นจุดที่ถูกบัง (Bubble Chart)

# %%
plt.scatter(df2['PetalLength'][:50] ,df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50]) #50 อันแรก #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5
plt.scatter(df2['PetalLength'][50:100] ,df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])  #50-100 #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5
plt.scatter(df2['PetalLength'][100:] ,df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='versicolor',s=40*df2['PetalWidth'][100:])  #100 สุดท้าย #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5
plt.legend()  #โชว์ชื่อแต่ละจุดที่พล็อตไปด้วย
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
plt.title('comparing petal & sepal length of different iris flowers'); #ตั้งชื่อกราฟ

# %% [markdown]
# ## เปลี่ยน หน้าตาของ Marker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50] ,df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='X') #50 อันแรก #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5 #เปลี่ยนจากจุดเป็นรูป X
plt.scatter(df2['PetalLength'][50:100] ,df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='X')  #50-100 #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5 #เปลี่ยนจากจุดเป็นรูป X
plt.scatter(df2['PetalLength'][100:] ,df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='versicolor',s=40*df2['PetalWidth'][100:],marker='X')  #100 สุดท้าย #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5 #เปลี่ยนจากจุดเป็นรูป X
plt.legend()  #โชว์ชื่อแต่ละจุดที่พล็อตไปด้วย
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
plt.title('comparing petal & sepal length of different iris flowers'); #ตั้งชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50] ,df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='$s$') #50 อันแรก #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5 #เปลี่ยนจากจุดเป็นรูป s
plt.scatter(df2['PetalLength'][50:100] ,df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='$c$')  #50-100 #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5 #เปลี่ยนจากจุดเป็นรูป c
plt.scatter(df2['PetalLength'][100:] ,df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='versicolor',s=40*df2['PetalWidth'][100:],marker='$g$')  #100 สุดท้าย #เพิ่มขนาด 40 เท่าของภาพเดิม #ปรับค่าความโปร่งใสเป็น 0.5 #เปลี่ยนจากจุดเป็นรูป g
plt.legend()  #โชว์ชื่อแต่ละจุดที่พล็อตไปด้วย
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
plt.title('comparing petal & sepal length of different iris flowers'); #ตั้งชื่อกราฟ

# %% [markdown]
# ## แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection = "3d") #ตัวแกนเปลี่ยนมาพล็อตแบบ 3 มิติแทน
ax.scatter(df2['PetalLength'],df2['SepalWidth'],df2['SepalLength'],c=df2['Name'],s=80*df2['PetalWidth']) #แกน 3 มิติมาพล็อตธรรมดาเลย

# %%
ax = plt.axes(projection = "3d") #ตัวแกนเปลี่ยนมาพล็อตแบบ 3 มิติแทน
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa') #50 อันแรก #เพิ่มขนาด 80 เท่าของภาพเดิม 
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor') #50 ถึง 100 #เพิ่มขนาด 80 เท่าของภาพเดิม 
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginica') #100 สุดท้าย #เพิ่มขนาด 80 เท่าของภาพเดิม 
plt.legend()  #โชว์ชื่อแต่ละจุดที่พล็อตไปด้วย
plt.xlabel('PetalLength') #ทำการเปลี่ยนชื่อแกน x
plt.ylabel('SepalLength') #ทำการเปลี่ยนชื่อแกน y
plt.title('comparing petal & sepal length of different iris flowers'); #ตั้งชื่อกราฟ

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![1*2c21SkzJMf3frPXPAR_gZA-2.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt #import ข้อมูลเข้า

# %%
plt.boxplot(df['SepalLength']) #ลองพล็อตบล็อกพ็อตของข้อมูล SepalLength
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6619fc1990>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f66187479d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f661874da10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f661874d4d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6619fc1f10>,
#   <matplotlib.lines.Line2D at 0x7f6618747490>]}

# %%
plt.boxplot(df['SepalLength'],vert=False) #Vert ถ้า True จะเป็นแนวตั้ง ถ้า เป็น False จะเป็นแนวนอน
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f6618734350>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6618739390>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f66187413d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6618739e50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f66187348d0>,
#   <matplotlib.lines.Line2D at 0x7f6618734e10>]}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False) #เอา ypb มารับค่า จะเห็นค่าส่วนอธิบายหายไป #Vert ถ้า True จะเป็นแนวตั้ง ถ้า เป็น False จะเป็นแนวนอน

# %% [markdown]
# - median

# %%
ybp['medians'][0].get_ydata() #แสดงค่า median โดยชี้ตัวที่ 0 ของแกน y
# Out:
# array([0.925, 1.075])

# %%
ybp['medians'][0].get_xdata() #แสดงค่า median โดยชี้ตัวที่ 0 ของแกน x
# Out:
# array([5.8, 5.8])

# %%
ybp['whiskers'][0].get_xdata() #แสดงค่า มากสุดน้อยสุด โดยชี้ตัวที่ 0 ของแกน x
# Out:
# array([5.1, 4.3])

# %% [markdown]
# - min

# %%
min(ybp['whiskers'][0].get_xdata())  #แสดงค่า น้อยสุด โดยชี้ตัวที่ 0 ของแกน x
# Out:
# 4.3

# %% [markdown]
# - mix

# %%
max(ybp['whiskers'][1].get_xdata())  #แสดงค่า มากสุด โดยชี้ตัวที่ 1 ของแกน x
# Out:
# 7.9

# %%
ybp['caps'][1].get_xdata()  #แสดงค่า มากสุด โดยชี้ตัวที่ 1 ของแกน x ใช้ cap ได้เหมือนกับ whiskers
# Out:
# array([7.9, 7.9])

# %% [markdown]
# - Q1

# %%
ybp['boxes'][0].get_xdata() #หาค่า Q1 โดยชี้ตัวที่ 0 จากแกน x
# Out:
# array([5.1, 5.1, 6.4, 6.4, 5.1])

# %%
ybp['boxes'][0].get_xdata()[0] #หาค่ Q1 โดยชี้ข้อมูลตัวที่ 0 จากแกน x และเป้นตัวแรก
# Out:
# 5.1

# %%
max(ybp['whiskers'][0].get_xdata()) #หา Q1 จาก whiskers ก็ได้
# Out:
# 5.1

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True) #Vert ถ้า True จะเป็นแนวตั้ง ถ้า เป็น False จะเป็นแนวนอน #ให้แสดงค่า mean เป็น 3 เหลี่ยม
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f66186ce510>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f66186d6450>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6619f8e890>],
#  'means': [<matplotlib.lines.Line2D at 0x7f661c14ec50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6618765cd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f6618745750>,
#   <matplotlib.lines.Line2D at 0x7f6618662950>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline=True,showmeans=True) #Vert ถ้า True จะเป็นแนวตั้ง ถ้า เป็น False จะเป็นแนวนอน #ให้แสดงค่า mean เป็นเส้นประ
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f661c231f10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f661c177610>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f661c2827d0>],
#  'means': [<matplotlib.lines.Line2D at 0x7f661c0ebb10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f661c0eb210>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f661c231890>,
#   <matplotlib.lines.Line2D at 0x7f6623df5650>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'o'})  #Vert ถ้า True จะเป็นแนวตั้ง ถ้า เป็น False จะเป็นแนวนอน #ให้แสดงค่า mean เป็น o
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f661c336750>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f661c2f7210>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f661c2ee090>],
#  'means': [<matplotlib.lines.Line2D at 0x7f661c2ee2d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f661c2eeb50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f661c3363d0>,
#   <matplotlib.lines.Line2D at 0x7f661c2f7690>]}

# %% [markdown]
# # Quiz กลุ่ม final
#
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3
# 2. วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %% [markdown]
# - ข้อที่ 1 เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False) #กรณีบล็อกพ็อตเป็นแนวนอน #ความยาวของกลีบเลี้ยง

# %%
def box_vals(ybq):  #สร้างฟังก์ชัน  รับค่า input
    q1 = ybp['boxes'][0].get_xdata()[0]  #หา q1
    q2 = ybp['medians'][0].get_xdata()[0]   #หา q2
    q3 = ybp['boxes'][0].get_xdata()[2]  #หา q3
    iqr = q3-q1
    vmin = min(ybp['caps'][0].get_xdata()) #ค่าน้อย
    vmax = max(ybp['caps'][1].get_xdata()) #ค่ามาก
    print(f'Q1 = {q1}')
    print(f'Q2 = {q2}')
    print(f'Q3 = {q3}')
    print(f'min = {vmin}')
    print(f'max = {vmax}')
    return

# %%
box_vals(df) #แสดงค่าทั้งหมดออกมา
# Out:
# Q1 = 5.1
# Q2 = 5.8
# Q3 = 6.4
# min = 4.3
# max = 7.9

# %%
x = plt.boxplot(df['SepalWidth'],vert=False) #กรณีบล็อกพ็อตเป็นแนวนอน #ความกว้างของกลีบเลี้ยง

# %%
def box_vals(x):  #สร้างฟังก์ชัน  รับค่า input
    q1 = x['boxes'][0].get_xdata()[0]  #หา q1
    q2 = x['medians'][0].get_xdata()[0]   #หา q2
    q3 = x['boxes'][0].get_xdata()[2]  #หา q3
    iqr = q3-q1
    vmin = min(x['caps'][0].get_xdata()) #ค่าน้อย
    vmax = max(x['caps'][1].get_xdata()) #ค่ามาก
    print(f'Q1 = {q1}')
    print(f'Q2 = {q2}')
    print(f'Q3 = {q3}')
    print(f'min = {vmin}')
    print(f'max = {vmax}')
    return

# %%
box_vals(x) #แสดงค่าทั้งหมดออกมา
# Out:
# Q1 = 2.8
# Q2 = 3.0
# Q3 = 3.3
# min = 2.2
# max = 4.0

# %% [markdown]
# - ข้อ 2 วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %%
setsosa = plt.boxplot(df2['PetalLength'][:50],vert=False)  #ใช้ vert=False  เป็นบล็อกพ็อตแนวนอน  #50 ดอกแรก #setosa

# %%
versicolor = plt.boxplot(df2['PetalLength'][51:100],vert=False)   #ใช้ vert=False  เป็นบล็อกพ็อตแนวนอน ดอกที่ 51-100 #versicolo

# %%
verginiga = plt.boxplot(df2['PetalLength'][101:],vert=False)  #ใช้ vert=False  เป็นบล็อกพ็อตแนวนอน  #verginiga

# %% [markdown]
# - เฉลยตามอาจารย์

# %%
bb = plt.boxplot(df['SepalLength'],vert=True)  #กรณีบล็อกพ๊อตเป้นแนวตั้ง

# %%
def detail_boxreturn(boxreturn):
  q1 = boxreturn['boxes'][0].get_ydata()[0]
  q2 = boxreturn['medians'][0].get_ydata() [0]
  q3 = boxreturn['boxes'][0].get_ydata()[2]
  minv = min(boxreturn['whiskers'][0].get_ydata())
  maxv = max(boxreturn['whiskers'][1].get_ydata())
  print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q3}, q3 = {q3}')

# %%
detail_boxreturn(bb) #รันค่าออกมา
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 6.4, q3 = 6.4

# %%
bb2 = plt.boxplot(df['SepalLength'],vert=False) #กรณีบล็อกพ๊อตเป้นแนวนอน

# %%
detail_boxreturn(bb2) #รันค่าออกมา
# Out:
# min = 1.0, max = 1.0, q1 = 0.925, q2 = 1.075, q3 = 1.075

# %%
def detail_boxreturn_v2(boxreturn, vert=True): 
    if vert ==True:
        q1 = boxreturn['boxes'][0].get_ydata()[0]
        q2 = boxreturn['medians'][0].get_ydata()[0]
        q3 = boxreturn['boxes'][0].get_ydata()[2]
        minv = min(boxreturn['whiskers'][0].get_ydata())
        maxv = max(boxreturn['whiskers'][1].get_ydata())
    else: # vert == False
        q1 = boxreturn['boxes'][0].get_xdata()[0]
        q2 = boxreturn['medians'][0].get_xdata()[0]
        q3 = boxreturn['boxes'][0].get_xdata()[2]
        minv = min(boxreturn['whiskers'][0].get_xdata())
        maxv = max(boxreturn['whiskers'][1].get_xdata())

    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn_v2(bb) #รันค่าออกมาดู
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
detail_boxreturn_v2(bb2,vert=False) #รันค่าออกมาดู
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
plt.boxplot(df['PetalLength'][:50],positions = [1] ) #positions ตัวที่ 1 #50 ตัวแรก
plt.boxplot(df['PetalLength'][50:100],positions = [2] ) #positions ตัวที่ 1 #50 - 100
plt.boxplot(df['PetalLength'][100:150],positions = [3] ); #positions ตัวที่ 1 #100 - 150

# %% [markdown]
# # Violin plot
#
# ดูแค่การกระจาย ไม่กำจัด outlier

# %%
bb = plt.boxplot(df['PetalLength'][:50])

# %%
plt.violinplot(df['PetalLength'][:50],showmeans=True) #ขอบเขตของ data และมี distribution ด้วยว่า เบ้ไปทางด้านไหน
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f661c60fa90>],
#  'cbars': <matplotlib.collections.LineCollection at 0x7f661c247b10>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f661c57b390>,
#  'cmeans': <matplotlib.collections.LineCollection at 0x7f661c60fe50>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f661c57ba10>}

# %%
plt.subplot(1,2,1)
bb = plt.boxplot(df['PetalLength'][:50])
q1 = bb['boxes'][0].get_ydata()[0]
q2 = bb['medians'][0].get_ydata()[0]
q3 = bb['boxes'][0].get_ydata()[2]
plt.subplot(1,2,2)
vi = plt.violinplot(df['PetalLength'][:50],showmedians=True) #เปรียบเทียบ   boxplot กับ violin plot

# %% [markdown]
# - HW ทดลอง plot ค่า quantile ลงไปในกราฟ (ศึกษาตัวแปล quantiles)

# %%
plt.subplot(1,2,1)
bb = plt.boxplot(df['PetalLength'][:50])
q1 = bb['boxes'][0].get_ydata()[0]
q2 = bb['medians'][0].get_ydata()[0]
q3 = bb['boxes'][0].get_ydata()[2]
plt.subplot(1,2,2)
vi = plt.violinplot(df['PetalLength'][:50],showmedians=True,quantiles=[0.25,0.5,0.75])
